# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
df = pd.DataFrame(np.random.randint(0,100,size=(15, 4)), columns=list('ABCD'))
df.head(3)
# Out:
#     A   B   C   D
# 0  20  44  64  24
# 1  55  79  34  73
# 2  56  74  48  92

# %%
df.plot()
# Out:
# <AxesSubplot:>
